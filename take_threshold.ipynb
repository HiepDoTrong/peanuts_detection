# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

# %%
img = cv.imread('/home/dotronghiep/Documents/Research/Peanuts_Anomaly_Detection_PAD/test_red/color_images/1.png')
plt.imshow(img[:,:,::-1])

# %%
# crop a small image from img above and save it
crop_img = img[85:165, 710:752]
plt.imshow(crop_img[:,:,::-1])

# %%
plt.imshow(crop_img[:,:,2], cmap='gray')

# %%
gray = img[:,:,1]
plt.imshow(gray, cmap='gray')

# %%
mask = cv.inRange(gray, 0, 70)
# threshold split for the image
plt.imshow(mask, cmap='gray')

# %%
gray2 = img[:,:,2]
plt.imshow(gray2, cmap='gray')

# %%
mask2 = cv.inRange(gray2, 200, 255)
plt.imshow(mask2, cmap='gray')

# %%
result = (mask + mask2)/2
plt.imshow(result, cmap='gray')
